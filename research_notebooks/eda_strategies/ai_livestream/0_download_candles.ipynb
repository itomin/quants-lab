# %%
from core.data_sources.clob import CLOBDataSource
import warnings

warnings.filterwarnings("ignore")

# Get trading rules and candles
clob = CLOBDataSource()

# %%
# Constants
CONNECTOR_NAME = "binance"
INTERVAL = "1s"
TRADING_PAIR = "BTC-USDT"
DAYS = 3

# %% [markdown]
# # Download data
# - Get trading rules
# - Get candles for the last x days

# %%
await clob.get_candles_last_days(CONNECTOR_NAME, TRADING_PAIR, INTERVAL, DAYS)
clob.dump_candles_cache()
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 await clob.get_candles_last_days(CONNECTOR_NAME, TRADING_PAIR, INTERVAL, DAYS)
#       2 clob.dump_candles_cache()
#
# File ~/dev/quants-lab/core/data_sources/clob.py:278, in CLOBDataSource.get_candles_last_days(self, connector_name, trading_pair, interval, days, from_trades)
#     276 end_time = int(time.time())
#     277 start_time = end_time - days * 24 * 60 * 60
# --> 278 return await self.get_candles(connector_name, trading_pair, interval, start_time, end_time, from_trades)
#
# File ~/dev/quants-lab/core/data_sources/clob.py:232, in CLOBDataSource.get_candles(self, connector_name, trading_pair, interval, start_time, end_time, from_trades)
#     226 else:
#     227     candle = self.candles_factory.get_candle(CandlesConfig(
#     228         connector=connector_name,
#     229         trading_pair=trading_pair,
#     230         interval=interval
#     231     ))
# --> 232     candles_df = await candle.get_historical_candles(HistoricalCandlesConfig(
#     233         connector_name=connector_name,
#     234         trading_pair=trading_pair,
#     235         start_time=fetch_start,
#     236         end_time=fetch_end,
#     237         interval=interval
#     238     ))
#     239     if candles_df is None or candles_df.empty:
#     240         continue
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py:172, in CandlesBase.get_historical_candles(self, config)
#     170 while current_end_time >= current_start_time:
#     171     missing_records = int((current_end_time - current_start_time) / self.interval_in_seconds)
# --> 172     candles = await self.fetch_candles(start_time=current_start_time,
#     173                                        end_time=current_end_time,
#     174                                        limit=missing_records)
#     175     if len(candles) <= 1 or missing_records == 0:
#     176         fetched_candles_df = pd.DataFrame(candles, columns=self.columns)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py:258, in CandlesBase.fetch_candles(self, start_time, end_time, limit)
#     256 headers = self._get_rest_candles_headers()
#     257 rest_assistant = await self._api_factory.get_rest_assistant()
# --> 258 candles = await rest_assistant.execute_request(url=self.candles_url,
#     259                                                throttler_limit_id=self._rest_throttler_limit_id,
#     260                                                params=params,
#     261                                                data=self._rest_payload(**kwargs),
#     262                                                headers=headers,
#     263                                                method=self._rest_method)
#     264 arr = self._parse_rest_candles(candles, end_time)
#     265 return np.array(arr).astype(float)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py:48, in RESTAssistant.execute_request(self, url, throttler_limit_id, params, data, method, is_auth_required, return_err, timeout, headers)
#      36 async def execute_request(
#      37     self,
#      38     url: str,
#    (...)     46     headers: Optional[Dict[str, Any]] = None,
#      47 ) -> Union[str, Dict[str, Any]]:
# ---> 48     response = await self.execute_request_and_get_response(
#      49         url=url,
#      50         throttler_limit_id=throttler_limit_id,
#      51         params=params,
#      52         data=data,
#      53         method=method,
#      54         is_auth_required=is_auth_required,
#      55         return_err=return_err,
#      56         timeout=timeout,
#      57         headers=headers,
#      58     )
#      59     response_json = await response.json()
#      60     return response_json
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py:95, in RESTAssistant.execute_request_and_get_response(self, url, throttler_limit_id, params, data, method, is_auth_required, return_err, timeout, headers)
#      84 request = RESTRequest(
#      85     method=method,
#      86     url=url,
#    (...)     91     throttler_limit_id=throttler_limit_id
#      92 )
#      94 async with self._throttler.execute_task(limit_id=throttler_limit_id):
# ---> 95     response = await self.call(request=request, timeout=timeout)
#      97     if 400 <= response.status:
#      98         if not return_err:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py:109, in RESTAssistant.call(self, request, timeout)
#     107 request = await self._pre_process_request(request)
#     108 request = await self._authenticate(request)
# --> 109 resp = await wait_for(self._connection.call(request), timeout)
#     110 resp = await self._post_process_response(resp)
#     111 return resp
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/quants-lab/lib/python3.12/asyncio/tasks.py:520, in wait_for(fut, timeout)
#     517         raise TimeoutError from exc
#     519 async with timeouts.timeout(timeout):
# --> 520     return await fut
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/connections/rest_connection.py:10, in RESTConnection.call(self, request)
#       9 async def call(self, request: RESTRequest) -> RESTResponse:
# ---> 10     aiohttp_resp = await self._client_session.request(
#      11         method=request.method.value,
#      12         url=request.url,
#      13         params=request.params,
#      14         data=request.data,
#      15         headers=request.headers,
#      16     )
#      18     resp = await self._build_resp(aiohttp_resp)
#      19     return resp
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/quants-lab/lib/python3.12/site-packages/aiohttp/client.py:779, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size, middlewares)
#     776     handler = _connect_and_send_request
#     778 try:
# --> 779     resp = await handler(req)
#     780 # Client connector errors should not be retried
#     781 except (
#     782     ConnectionTimeoutError,
#     783     ClientConnectorError,
#     784     ClientConnectorCertificateError,
#     785     ClientConnectorSSLError,
#     786 ):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/quants-lab/lib/python3.12/site-packages/aiohttp/client.py:757, in ClientSession._request.<locals>._connect_and_send_request(req)
#     755 resp = await req.send(conn)
#     756 try:
# --> 757     await resp.start(conn)
#     758 except BaseException:
#     759     resp.close()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/quants-lab/lib/python3.12/site-packages/aiohttp/client_reqrep.py:539, in ClientResponse.start(self, connection)
#     537 try:
#     538     protocol = self._protocol
# --> 539     message, payload = await protocol.read()  # type: ignore[union-attr]
#     540 except http.HttpProcessingError as exc:
#     541     raise ClientResponseError(
#     542         self.request_info,
#     543         self.history,
#    (...)    546         headers=exc.headers,
#     547     ) from exc
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/quants-lab/lib/python3.12/site-packages/aiohttp/streams.py:680, in DataQueue.read(self)
#     678 self._waiter = self._loop.create_future()
#     679 try:
# --> 680     await self._waiter
#     681 except (asyncio.CancelledError, asyncio.TimeoutError):
#     682     self._waiter = None
#
# CancelledError:

# %%
btc_candles = clob.candles_cache[("binance", "BTC-USDT", "1s")]

# %%
btc_candles.plot()

# %%
btc_candles.data
